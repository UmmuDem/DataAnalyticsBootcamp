# %% [markdown]
# ## ghfg

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
cd Documents
# Out:
# [Errno 2] No such file or directory: 'Documents'
# /Users/ummuhandemir/Documents/GitHub/Ummuhan/Week1

# %%
cd GitHub
# Out:
# [Errno 2] No such file or directory: 'GitHub'
# /Users/ummuhandemir/Documents/GitHub/Ummuhan/Week1

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df['gender'].value_counts().plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:>

# %%
df['race/ethnicity'].value_counts().plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:>

# %%
df['parental level of education'].value_counts().plot(kind='bar',color='red')
# Out:
# <AxesSubplot:>

# %%
dfnum = df._get_numeric_data()
dfnum
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
dfnum.hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %%
df['mean of all scores'] = df.mean(numeric_only=True, axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    mean of all scores
# 0           72.666667
# 1           82.333333
# 2           92.666667
# 3           49.333333
# 4           76.333333

# %%
dfplot = sns.catplot(x="race/ethnicity", y="math score", hue="gender",data=df, kind="violin")

# %%
sns.catplot(x="test preparation course", y="math score", hue="gender",data=df, kind="bar", dodge = True)

# %%
dfplot = sns.catplot(x="test preparation course", y="mean of all scores", hue="gender",data=df, kind="bar")

# %%
dfplot = sns.catplot(x="gender", y="writing score", hue="gender",data=df, kind="bar")

# %%
sns.catplot(x="race/ethnicity", y="math score", hue="gender",data=df, kind="bar")
