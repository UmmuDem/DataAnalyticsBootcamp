# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd GitHub
# Out:
# [Errno 2] No such file or directory: 'GitHub'
# /Users/ummuhandemir/Documents/GitHub

# %%
df = pd.read_csv('oct_22.csv')

# %%
sns.scatterplot(data=df, x="swine_population", y="atmospheric_ammonia")
# Out:
# <AxesSubplot:xlabel='swine_population', ylabel='atmospheric_ammonia'>

# %%
correlations_matrix = df.corr()
correlations_matrix
sns.heatmap(correlations_matrix,annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='swine_population', y='atmospheric_ammonia', data=df)
# Out:
# <AxesSubplot:xlabel='swine_population', ylabel='atmospheric_ammonia'>

# %%
x= df['swine_population']
y = df['atmospheric_ammonia']
x_mean = np.mean(x)
y_mean = np.mean(y)
x_mean,y_mean
  
Sxy = np.sum(x*y)- len(x)*x_mean*y_mean
Sxx = np.sum(x*x)-len(x)*x_mean*x_mean
  
b1 = Sxy/Sxx
b0 = y_mean-b1*x_mean
print('slope b1 is', b1)
print('intercept b0 is', b0)
  
plt.scatter(x,y)
plt.xlabel('Independent variable X')
plt.ylabel('Dependent variable y')
# Out:
# slope b1 is 0.13251898994046424
# intercept b0 is 0.12716895914596557
# Text(0, 0.5, 'Dependent variable y')
